# %% [markdown]
# # PNEUMONIA CLASSIFIER
# ## BIL 443 TERM PROJECT
# ### Mert Başar Yıldırım | 211101039

# %% [markdown]
# ## Imports

# %%
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import KFold
from sklearn.utils.class_weight import compute_class_weight
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import regularizers
import os
import random
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
import warnings
warnings.filterwarnings ('ignore')
print ("tensorflow version is:",tf.__version__)
# Out:
# tensorflow version is: 2.18.0

# %% [markdown]
# ### Checking if the dataset is loaded correctly.

# %%
xray_data_dir = "../data/chest_xray"
print(os.listdir(xray_data_dir))
# Out:
# ['chest_xray', 'test', 'train', 'val']

# %% [markdown]
# ### Defining file paths

# %%
train_folder = os.path.join(xray_data_dir, "train")
test_folder = os.path.join(xray_data_dir, "test")
val_folder = os.path.join(xray_data_dir, "val")

# %% [markdown]
# ### A function for loading dataset images for each class

# %%
def load_images_from_directory(directory, image_size=(256, 256)):
    images = []
    labels = []
    class_names = sorted(os.listdir(directory))  

    for label, class_name in enumerate(class_names):
        class_path = os.path.join(directory, class_name)

        if os.path.isdir(class_path):  
            for img_name in os.listdir(class_path):
                img_path = os.path.join(class_path, img_name)
                try:
                    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
                    img = cv2.resize(img, image_size)  
                    img = np.expand_dims(img, axis=-1)  
                    images.append(img)
                    labels.append(label)
                except Exception as e:
                    print(f"Error occurred: {img_path}, Error: {e}")  

    return np.array(images), np.array(labels), class_names

# %%
try:
    X_train, y_train, class_names = load_images_from_directory(train_folder)
    X_test, y_test, _ = load_images_from_directory(test_folder)
    X_val, y_val, _ = load_images_from_directory(val_folder)

    print(f"Classes: {class_names}")
    print(f"Train dataset shape: {X_train.shape}, Labels shape: {y_train.shape}")
    print(f"Test dataset shape: {X_test.shape}, Labels shape: {y_test.shape}")
    print(f"Validation dataset shape: {X_val.shape}, Labels shape: {y_val.shape}")
except Exception as e:
    print("Error occured:", e)
# Out:
# Classes: ['NORMAL', 'PNEUMONIA']
# Train dataset shape: (5216, 256, 256, 1), Labels shape: (5216,)
# Test dataset shape: (624, 256, 256, 1), Labels shape: (624,)
# Validation dataset shape: (16, 256, 256, 1), Labels shape: (16,)

# %%
def plot_sample_images(X, y, class_names, samples_per_class=10):
    num_classes = len(class_names)
    fig, axes = plt.subplots(num_classes, samples_per_class, figsize=(samples_per_class * 2, num_classes * 2))
    fig.tight_layout(pad=3.0)
    
    for i, class_name in enumerate(class_names):
        class_indices = np.where(y == i)[0]  # Bu sınıfa ait resimlerin indeksleri
        selected_indices = random.sample(list(class_indices), min(len(class_indices), samples_per_class))  # Rastgele seç
        for j, idx in enumerate(selected_indices):
            axes[i, j].imshow(X[idx].squeeze(), cmap='gray')
            axes[i, j].axis('off')
            if j == 0:  # İlk sütunda sınıf adı göster
                axes[i, j].set_title(class_name, fontsize=12)

    plt.show()

# %%
plot_sample_images(X_train, y_train, class_names, samples_per_class=10)

# %% [markdown]
# ## The Distribution of Dataset

# %%
plt.figure(figsize=(6, 6))
plt.pie(x=[len(y_train), len(y_val), len(y_test)], labels=["Training", "Validation", "Test"], autopct='%1.1f%%', startangle=80, colors=['#ff9999','#66b3ff','#99ff99'])
plt.title("Dataset Distribution (Train / Validation / Test)")
plt.show()

# %% [markdown]
# ## Distribution of dataset classes

# %%
labels = [
    "Training-Normal", "Training-Pneumonia",
    "Validation-Normal", "Validation-Pneumonia",
    "Test-Normal", "Test-Pneumonia"
]
colors = ["red", "red", "blue", "blue", "green", "green"]

train_counts = [np.sum(y_train == 0), np.sum(y_train == 1)]
val_counts = [np.sum(y_val == 0), np.sum(y_val == 1)]
test_counts = [np.sum(y_test == 0), np.sum(y_test == 1)]
class_counts = train_counts + val_counts + test_counts

print("train-normal: "      + str(np.sum(y_train == 0)))
print("train-pneumonia: "   + str(np.sum(y_train == 1)))
print("val-normal: "        + str(np.sum(y_val == 0)))
print("val-pneumonia: "     + str(np.sum(y_val == 1)))
print("test-normal: "       + str(np.sum(y_test == 0)))
print("test-pneumonia: "    + str(np.sum(y_test == 1)))
# Out:
# train-normal: 1341
# train-pneumonia: 3875
# val-normal: 8
# val-pneumonia: 8
# test-normal: 234
# test-pneumonia: 390

# %%
# Create the bar chart
plt.figure(figsize=(10, 6))
plt.bar(labels, height=class_counts, color=['#ff9999', '#ff6666', '#66b3ff', '#3380cc', '#99ff99', '#33cc33'])
plt.xlabel("Categories")
plt.ylabel("Count")
plt.title("Distribution of Classes in Training, Validation, and Test Sets")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Data Preprocessing
# - Input images are converted to grayscale to enhance feature extraction efficiency.
# - All images are resized to a uniform shape of (256, 256, 1) to maintain consistency.
# - Pixel values are normalized to the [0,1] range to improve model performance.
# - The dataset is initially combined and then stratified into 80% training and 20% validation to ensure balanced representation.
# - K-Fold Cross-Validation is implemented with k = 5 to enhance model generalization.
# - Class weights are assigned to address class imbalance and improve model learning.

# %%
X_train = X_train / 255.0
X_val = X_val / 255.0
X_test = X_test / 255.0

# %%
X_combined = np.concatenate((X_train, X_val), axis=0)
y_combined = np.concatenate((y_train, y_val), axis=0)

# %%
k = 5
kf = KFold(n_splits=k, shuffle=True, random_state=42)

# %%
train_counts_list = []
val_counts_list = []

# Compute class distributions for each fold
for train_idx, val_idx in kf.split(y_combined):
    y_train_fold, y_val_fold = y_combined[train_idx], y_combined[val_idx]

    train_counts_list.append(len(y_train_fold))
    val_counts_list.append(len(y_val_fold))

avg_train_size = np.mean(train_counts_list)
avg_val_size = np.mean(val_counts_list)

# %%
plt.figure(figsize=(6, 6))
plt.pie([avg_train_size, avg_val_size, len(y_test)],
        labels=["Training", "Validation", "Test"],
        autopct='%1.1f%%', startangle=80,
        colors=['#ff9999', '#66b3ff', '#99ff99'])
plt.title("Dataset Distribution (Train / Validation / Test)")
plt.show()

# %%
train_class_0_list = []
train_class_1_list = []
val_class_0_list = []
val_class_1_list = []

for train_idx, val_idx in kf.split(y_combined):
    y_train_fold, y_val_fold = y_combined[train_idx], y_combined[val_idx]

    # Count classes in train and validation sets
    train_class_0_list.append(np.sum(y_train_fold == 0))
    train_class_1_list.append(np.sum(y_train_fold == 1))
    val_class_0_list.append(np.sum(y_val_fold == 0))
    val_class_1_list.append(np.sum(y_val_fold == 1))

avg_train_class_0 = np.mean(train_class_0_list)
avg_train_class_1 = np.mean(train_class_1_list)
avg_val_class_0 = np.mean(val_class_0_list)
avg_val_class_1 = np.mean(val_class_1_list)
test_class_0 = np.sum(y_test == 0)
test_class_1 = np.sum(y_test == 1)

# Labels and class counts
class_counts = [avg_train_class_0, avg_train_class_1, avg_val_class_0, avg_val_class_1, test_class_0, test_class_1]

# %%
plt.figure(figsize=(10, 6))
plt.bar(labels, height=class_counts, color=['#ff9999', '#ff6666', '#66b3ff', '#3380cc', '#99ff99', '#33cc33'])
plt.xlabel("Categories")
plt.ylabel("Count")
plt.title("Distribution of Classes in Training, Validation and Test Sets")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %%
class_labels = np.unique(y_combined) 
class_weights = compute_class_weight(class_weight="balanced", classes=class_labels, y=y_combined)
class_weight_dict = dict(zip(class_labels, class_weights))

print("Class Weights:", class_weight_dict)
# Out:
# Class Weights: {0: 1.939214232765011, 1: 0.6737058975019315}

# %% [markdown]
# # Building the CNN Model

# %%
# Depthwise Separable Convolution
def build_model():
    model = tf.keras.models.Sequential([
        tf.keras.layers.SeparableConv2D(32, (3,3), activation='relu', input_shape=(256,256,1),
                                        depthwise_regularizer=regularizers.l2(0.01),
                                        pointwise_regularizer=regularizers.l2(0.01)),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPooling2D(),
        tf.keras.layers.Dropout(0.25),

        tf.keras.layers.SeparableConv2D(64, (3,3), activation='relu',
                                        depthwise_regularizer=regularizers.l2(0.01),
                                        pointwise_regularizer=regularizers.l2(0.01)),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPooling2D(),
        tf.keras.layers.Dropout(0.25),

        tf.keras.layers.SeparableConv2D(128, (3,3), activation='relu',
                                        depthwise_regularizer=regularizers.l2(0.01),
                                        pointwise_regularizer=regularizers.l2(0.01)),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPooling2D(),
        tf.keras.layers.Dropout(0.25),

        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(0.5),

        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])
    return model

# %%
example_model = build_model()
example_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ separable_conv2d_2              │ (None, 254, 254, 32)   │            73 │
# │ (SeparableConv2D)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 254, 254, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 127, 127, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 127, 127, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ separable_conv2d_3              │ (None, 125, 125, 64)   │         2,400 │
# │ (SeparableConv2D)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 125, 125, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 62, 62, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 62, 62, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ separable_conv2d_4              │ (None, 60, 60, 128)    │         8,896 │
# │ (SeparableConv2D)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 60, 60, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 30, 30, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 30, 30, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 115200)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │     7,372,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,385,450 (28.17 MB)
#  Trainable params: 7,384,874 (28.17 MB)
#  Non-trainable params: 576 (2.25 KB)

# %%
#early_stopping = EarlyStopping(monitor='val_loss', patience=10, mode='min', verbose=1, restore_best_weights=True)
lr_reduction = ReduceLROnPlateau(monitor='val_loss', patience=3, verbose=1, factor=0.5, min_lr=0.0001)

# K-Fold Training
fold_no = 1
acc_per_fold = []
loss_per_fold = []
histories = []
best_accuracy = 0
best_loss = float('inf')
best_model = None
best_model_history = None

for train_idx, val_idx in kf.split(X_combined):
    print(f"\nTraining Fold {fold_no}/{k}...")

    # Train & Validation Data
    X_train_fold, X_val_fold = X_combined[train_idx], X_combined[val_idx]
    y_train_fold, y_val_fold = y_combined[train_idx], y_combined[val_idx]

    # Create a New Model for Each Fold
    model = build_model()

    # Train Model
    history = model.fit(X_train_fold, y_train_fold,
                        validation_data=(X_val_fold, y_val_fold),
                        epochs=25, batch_size=32,
                        callbacks=[lr_reduction],
                        class_weight=class_weight_dict  
                    )

    histories.append(history)

    # Evaluate Model on Validation Set
    loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
    print(f"Fold {fold_no} - Loss: {loss:.4f}, Accuracy: {accuracy:.4f}")

    # Best Model Selection Logic
    if accuracy > best_accuracy or (accuracy == best_accuracy and loss < best_loss):
        best_accuracy = accuracy
        best_loss = loss
        best_model = model
        best_model_history = history

    loss_per_fold.append(loss)
    acc_per_fold.append(accuracy)

    fold_no += 1
# Out:
# Training Fold 1/5...
# Epoch 1/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - accuracy: 0.8112 - loss: 3.3480 - val_accuracy: 0.7230 - val_loss: 3.1392 - learning_rate: 0.0010
# Epoch 2/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 256s 2s/step - accuracy: 0.9289 - loss: 1.2758 - val_accuracy: 0.7230 - val_loss: 6.7079 - learning_rate: 0.0010
# Epoch 3/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 256s 2s/step - accuracy: 0.9390 - loss: 0.8425 - val_accuracy: 0.7230 - val_loss: 10.0453 - learning_rate: 0.0010
# Epoch 4/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 256s 2s/step - accuracy: 0.9396 - loss: 1.1333 - val_accuracy: 0.7230 - val_loss: 3.0032 - learning_rate: 0.0010
# Epoch 5/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 257s 2s/step - accuracy: 0.9363 - loss: 0.8048 - val_accuracy: 0.7230 - val_loss: 2.4455 - learning_rate: 0.0010
# Epoch 6/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 255s 2s/step - accuracy: 0.9490 - loss: 0.6924 - val_accuracy: 0.9542 - val_loss: 0.7205 - learning_rate: 0.0010
# Epoch 7/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 247s 2s/step - accuracy: 0.9545 - loss: 0.7024 - val_accuracy: 0.9217 - val_loss: 1.1646 - learning_rate: 0.0010
# Epoch 8/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 246s 2s/step - accuracy: 0.9541 - loss: 0.8195 - val_accuracy: 0.9331 - val_loss: 0.6776 - learning_rate: 0.0010
# Epoch 9/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 245s 2s/step - accuracy: 0.9606 - loss: 0.5832 - val_accuracy: 0.9637 - val_loss: 0.7165 - learning_rate: 0.0010
# Epoch 10/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 246s 2s/step - accuracy: 0.9607 - loss: 0.6213 - val_accuracy: 0.7192 - val_loss: 1.2790 - learning_rate: 0.0010
# Epoch 11/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 247s 2s/step - accuracy: 0.9467 - loss: 0.5921 - val_accuracy: 0.9694 - val_loss: 0.6101 - learning_rate: 0.0010
# Epoch 12/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 253s 2s/step - accuracy: 0.9528 - loss: 0.6220 - val_accuracy: 0.9742 - val_loss: 0.6878 - learning_rate: 0.0010
# Epoch 13/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 247s 2s/step - accuracy: 0.9564 - loss: 0.5929 - val_accuracy: 0.9513 - val_loss: 1.0469 - learning_rate: 0.0010
# Epoch 14/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9617 - loss: 0.8029
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 248s 2s/step - accuracy: 0.9616 - loss: 0.8023 - val_accuracy: 0.7746 - val_loss: 1.2391 - learning_rate: 0.0010
# Epoch 15/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 247s 2s/step - accuracy: 0.9572 - loss: 0.5933 - val_accuracy: 0.9083 - val_loss: 0.5207 - learning_rate: 5.0000e-04
# Epoch 16/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 248s 2s/step - accuracy: 0.9648 - loss: 0.3773 - val_accuracy: 0.9704 - val_loss: 0.3630 - learning_rate: 5.0000e-04
# Epoch 17/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 247s 2s/step - accuracy: 0.9683 - loss: 0.3179 - val_accuracy: 0.9513 - val_loss: 0.3381 - learning_rate: 5.0000e-04
# Epoch 18/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 247s 2s/step - accuracy: 0.9520 - loss: 0.3379 - val_accuracy: 0.9475 - val_loss: 0.3762 - learning_rate: 5.0000e-04
# Epoch 19/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 247s 2s/step - accuracy: 0.9677 - loss: 0.3079 - val_accuracy: 0.9169 - val_loss: 0.4467 - learning_rate: 5.0000e-04
# Epoch 20/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9765 - loss: 0.2648
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 247s 2s/step - accuracy: 0.9764 - loss: 0.2649 - val_accuracy: 0.9417 - val_loss: 0.3676 - learning_rate: 5.0000e-04
# Epoch 21/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 247s 2s/step - accuracy: 0.9764 - loss: 0.2728 - val_accuracy: 0.9704 - val_loss: 0.2447 - learning_rate: 2.5000e-04
# Epoch 22/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 247s 2s/step - accuracy: 0.9848 - loss: 0.1982 - val_accuracy: 0.9675 - val_loss: 0.2246 - learning_rate: 2.5000e-04
# Epoch 23/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 248s 2s/step - accuracy: 0.9818 - loss: 0.1880 - val_accuracy: 0.9780 - val_loss: 0.2048 - learning_rate: 2.5000e-04
# Epoch 24/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 248s 2s/step - accuracy: 0.9822 - loss: 0.1745 - val_accuracy: 0.9503 - val_loss: 0.2849 - learning_rate: 2.5000e-04
# Epoch 25/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 248s 2s/step - accuracy: 0.9810 - loss: 0.1783 - val_accuracy: 0.9666 - val_loss: 0.2318 - learning_rate: 2.5000e-04
# Fold 1 - Loss: 0.9859, Accuracy: 0.7532
#
# Training Fold 2/5...
# Epoch 1/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 260s 2s/step - accuracy: 0.8125 - loss: 3.2250 - val_accuracy: 0.7431 - val_loss: 4.7130 - learning_rate: 0.0010
# Epoch 2/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 249s 2s/step - accuracy: 0.9276 - loss: 1.2175 - val_accuracy: 0.7431 - val_loss: 4.4378 - learning_rate: 0.0010
# Epoch 3/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 248s 2s/step - accuracy: 0.9160 - loss: 0.9082 - val_accuracy: 0.7431 - val_loss: 1.7892 - learning_rate: 0.0010
# Epoch 4/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 248s 2s/step - accuracy: 0.9393 - loss: 0.9930 - val_accuracy: 0.7431 - val_loss: 2.8974 - learning_rate: 0.0010
# Epoch 5/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 248s 2s/step - accuracy: 0.9496 - loss: 0.7876 - val_accuracy: 0.7431 - val_loss: 1.3829 - learning_rate: 0.0010
# Epoch 6/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 249s 2s/step - accuracy: 0.9404 - loss: 0.7428 - val_accuracy: 0.7918 - val_loss: 0.9739 - learning_rate: 0.0010
# Epoch 7/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 255s 2s/step - accuracy: 0.9469 - loss: 0.7782 - val_accuracy: 0.9379 - val_loss: 0.9142 - learning_rate: 0.0010
# Epoch 8/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 244s 2s/step - accuracy: 0.9376 - loss: 0.8591 - val_accuracy: 0.9494 - val_loss: 0.7709 - learning_rate: 0.0010
# Epoch 9/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 243s 2s/step - accuracy: 0.9441 - loss: 0.7353 - val_accuracy: 0.9150 - val_loss: 1.1077 - learning_rate: 0.0010
# Epoch 10/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 244s 2s/step - accuracy: 0.9376 - loss: 1.0348 - val_accuracy: 0.9293 - val_loss: 0.7622 - learning_rate: 0.0010
# Epoch 11/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 244s 2s/step - accuracy: 0.9553 - loss: 0.7012 - val_accuracy: 0.9637 - val_loss: 0.6649 - learning_rate: 0.0010
# Epoch 12/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 245s 2s/step - accuracy: 0.9522 - loss: 0.6395 - val_accuracy: 0.9532 - val_loss: 0.6310 - learning_rate: 0.0010
# Epoch 13/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 245s 2s/step - accuracy: 0.9555 - loss: 0.6034 - val_accuracy: 0.9570 - val_loss: 0.5539 - learning_rate: 0.0010
# Epoch 14/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 245s 2s/step - accuracy: 0.9560 - loss: 0.5398 - val_accuracy: 0.9274 - val_loss: 0.5623 - learning_rate: 0.0010
# Epoch 15/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 245s 2s/step - accuracy: 0.9589 - loss: 0.5209 - val_accuracy: 0.8223 - val_loss: 0.8081 - learning_rate: 0.0010
# Epoch 16/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9510 - loss: 0.5636
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 250s 2s/step - accuracy: 0.9510 - loss: 0.5638 - val_accuracy: 0.9465 - val_loss: 0.7457 - learning_rate: 0.0010
# Epoch 17/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 245s 2s/step - accuracy: 0.9576 - loss: 0.5879 - val_accuracy: 0.9618 - val_loss: 0.3916 - learning_rate: 5.0000e-04
# Epoch 18/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 245s 2s/step - accuracy: 0.9728 - loss: 0.3616 - val_accuracy: 0.9561 - val_loss: 0.3401 - learning_rate: 5.0000e-04
# Epoch 19/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 245s 2s/step - accuracy: 0.9673 - loss: 0.3136 - val_accuracy: 0.9522 - val_loss: 0.3351 - learning_rate: 5.0000e-04
# Epoch 20/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 245s 2s/step - accuracy: 0.9680 - loss: 0.3189 - val_accuracy: 0.9093 - val_loss: 0.5002 - learning_rate: 5.0000e-04
# Epoch 21/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 245s 2s/step - accuracy: 0.9703 - loss: 0.2944 - val_accuracy: 0.9207 - val_loss: 0.4031 - learning_rate: 5.0000e-04
# Epoch 22/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9684 - loss: 0.3334
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 246s 2s/step - accuracy: 0.9684 - loss: 0.3334 - val_accuracy: 0.9503 - val_loss: 0.3783 - learning_rate: 5.0000e-04
# Epoch 23/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 245s 2s/step - accuracy: 0.9749 - loss: 0.2955 - val_accuracy: 0.9551 - val_loss: 0.2923 - learning_rate: 2.5000e-04
# Epoch 24/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 245s 2s/step - accuracy: 0.9776 - loss: 0.2314 - val_accuracy: 0.9742 - val_loss: 0.2313 - learning_rate: 2.5000e-04
# Epoch 25/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 246s 2s/step - accuracy: 0.9791 - loss: 0.2179 - val_accuracy: 0.9647 - val_loss: 0.2539 - learning_rate: 2.5000e-04
# Fold 2 - Loss: 0.9513, Accuracy: 0.7756
#
# Training Fold 3/5...
# Epoch 1/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 250s 2s/step - accuracy: 0.8204 - loss: 3.1316 - val_accuracy: 0.2333 - val_loss: 4.9881 - learning_rate: 0.0010
# Epoch 2/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 247s 2s/step - accuracy: 0.9231 - loss: 1.1275 - val_accuracy: 0.7667 - val_loss: 1.1881 - learning_rate: 0.0010
# Epoch 3/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 248s 2s/step - accuracy: 0.9412 - loss: 0.8296 - val_accuracy: 0.7667 - val_loss: 1.6881 - learning_rate: 0.0010
# Epoch 4/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 249s 2s/step - accuracy: 0.9401 - loss: 0.8281 - val_accuracy: 0.7667 - val_loss: 1.5877 - learning_rate: 0.0010
# Epoch 5/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9493 - loss: 0.7213
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 253s 2s/step - accuracy: 0.9492 - loss: 0.7211 - val_accuracy: 0.7667 - val_loss: 1.3423 - learning_rate: 0.0010
# Epoch 6/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 245s 2s/step - accuracy: 0.9637 - loss: 0.5336 - val_accuracy: 0.9598 - val_loss: 0.4708 - learning_rate: 5.0000e-04
# Epoch 7/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 245s 2s/step - accuracy: 0.9682 - loss: 0.3795 - val_accuracy: 0.9818 - val_loss: 0.3553 - learning_rate: 5.0000e-04
# Epoch 8/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 245s 2s/step - accuracy: 0.9582 - loss: 0.3816 - val_accuracy: 0.8451 - val_loss: 0.6108 - learning_rate: 5.0000e-04
# Epoch 9/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 245s 2s/step - accuracy: 0.9587 - loss: 0.3725 - val_accuracy: 0.9579 - val_loss: 0.3444 - learning_rate: 5.0000e-04
# Epoch 10/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 245s 2s/step - accuracy: 0.9717 - loss: 0.3312 - val_accuracy: 0.2333 - val_loss: 8.2727 - learning_rate: 5.0000e-04
# Epoch 11/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 245s 2s/step - accuracy: 0.9630 - loss: 0.4000 - val_accuracy: 0.9771 - val_loss: 0.3477 - learning_rate: 5.0000e-04
# Epoch 12/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9641 - loss: 0.3534
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 246s 2s/step - accuracy: 0.9641 - loss: 0.3534 - val_accuracy: 0.9627 - val_loss: 0.3906 - learning_rate: 5.0000e-04
# Epoch 13/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 245s 2s/step - accuracy: 0.9734 - loss: 0.3353 - val_accuracy: 0.9866 - val_loss: 0.2436 - learning_rate: 2.5000e-04
# Epoch 14/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 244s 2s/step - accuracy: 0.9754 - loss: 0.2450 - val_accuracy: 0.9885 - val_loss: 0.2144 - learning_rate: 2.5000e-04
# Epoch 15/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 244s 2s/step - accuracy: 0.9802 - loss: 0.2207 - val_accuracy: 0.9780 - val_loss: 0.2117 - learning_rate: 2.5000e-04
# Epoch 16/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 246s 2s/step - accuracy: 0.9814 - loss: 0.2064 - val_accuracy: 0.9780 - val_loss: 0.2185 - learning_rate: 2.5000e-04
# Epoch 17/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 245s 2s/step - accuracy: 0.9785 - loss: 0.1975 - val_accuracy: 0.9742 - val_loss: 0.2344 - learning_rate: 2.5000e-04
# Epoch 18/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9783 - loss: 0.2018
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 245s 2s/step - accuracy: 0.9783 - loss: 0.2018 - val_accuracy: 0.9187 - val_loss: 0.3853 - learning_rate: 2.5000e-04
# Epoch 19/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 244s 2s/step - accuracy: 0.9788 - loss: 0.1879 - val_accuracy: 0.9665 - val_loss: 0.2180 - learning_rate: 1.2500e-04
# Epoch 20/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 251s 2s/step - accuracy: 0.9833 - loss: 0.1620 - val_accuracy: 0.9799 - val_loss: 0.1604 - learning_rate: 1.2500e-04
# Epoch 21/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 245s 2s/step - accuracy: 0.9884 - loss: 0.1455 - val_accuracy: 0.9876 - val_loss: 0.1444 - learning_rate: 1.2500e-04
# Epoch 22/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 245s 2s/step - accuracy: 0.9919 - loss: 0.1250 - val_accuracy: 0.9857 - val_loss: 0.1426 - learning_rate: 1.2500e-04
# Epoch 23/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 245s 2s/step - accuracy: 0.9879 - loss: 0.1347 - val_accuracy: 0.9742 - val_loss: 0.1858 - learning_rate: 1.2500e-04
# Epoch 24/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 252s 2s/step - accuracy: 0.9901 - loss: 0.1225 - val_accuracy: 0.9646 - val_loss: 0.2013 - learning_rate: 1.2500e-04
# Epoch 25/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9905 - loss: 0.1221
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0001.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 244s 2s/step - accuracy: 0.9905 - loss: 0.1221 - val_accuracy: 0.9818 - val_loss: 0.1462 - learning_rate: 1.2500e-04
# Fold 3 - Loss: 0.8454, Accuracy: 0.7869
#
# Training Fold 4/5...
# Epoch 1/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 248s 2s/step - accuracy: 0.7999 - loss: 3.2592 - val_accuracy: 0.7170 - val_loss: 6.4904 - learning_rate: 0.0010
# Epoch 2/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 257s 2s/step - accuracy: 0.9211 - loss: 1.2988 - val_accuracy: 0.7170 - val_loss: 7.3411 - learning_rate: 0.0010
# Epoch 3/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 256s 2s/step - accuracy: 0.9437 - loss: 0.9037 - val_accuracy: 0.7170 - val_loss: 5.3135 - learning_rate: 0.0010
# Epoch 4/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 254s 2s/step - accuracy: 0.9538 - loss: 0.7954 - val_accuracy: 0.7170 - val_loss: 1.4667 - learning_rate: 0.0010
# Epoch 5/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 254s 2s/step - accuracy: 0.9537 - loss: 0.9345 - val_accuracy: 0.9302 - val_loss: 1.7240 - learning_rate: 0.0010
# Epoch 6/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 254s 2s/step - accuracy: 0.9435 - loss: 1.2645 - val_accuracy: 0.9484 - val_loss: 0.7028 - learning_rate: 0.0010
# Epoch 7/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 255s 2s/step - accuracy: 0.9490 - loss: 0.7945 - val_accuracy: 0.9207 - val_loss: 1.0240 - learning_rate: 0.0010
# Epoch 8/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 253s 2s/step - accuracy: 0.9613 - loss: 0.7767 - val_accuracy: 0.9685 - val_loss: 0.5851 - learning_rate: 0.0010
# Epoch 9/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 259s 2s/step - accuracy: 0.9558 - loss: 0.5481 - val_accuracy: 0.8834 - val_loss: 0.6384 - learning_rate: 0.0010
# Epoch 10/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 254s 2s/step - accuracy: 0.9568 - loss: 0.6222 - val_accuracy: 0.9073 - val_loss: 0.6532 - learning_rate: 0.0010
# Epoch 11/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9538 - loss: 0.5161
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 255s 2s/step - accuracy: 0.9538 - loss: 0.5161 - val_accuracy: 0.9197 - val_loss: 0.6066 - learning_rate: 0.0010
# Epoch 12/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 254s 2s/step - accuracy: 0.9617 - loss: 0.4205 - val_accuracy: 0.9465 - val_loss: 0.3506 - learning_rate: 5.0000e-04
# Epoch 13/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 254s 2s/step - accuracy: 0.9696 - loss: 0.3042 - val_accuracy: 0.9398 - val_loss: 0.3718 - learning_rate: 5.0000e-04
# Epoch 14/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 255s 2s/step - accuracy: 0.9676 - loss: 0.3114 - val_accuracy: 0.9723 - val_loss: 0.3045 - learning_rate: 5.0000e-04
# Epoch 15/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 257s 2s/step - accuracy: 0.9673 - loss: 0.2921 - val_accuracy: 0.9704 - val_loss: 0.3226 - learning_rate: 5.0000e-04
# Epoch 16/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 257s 2s/step - accuracy: 0.9640 - loss: 0.3282 - val_accuracy: 0.9665 - val_loss: 0.3022 - learning_rate: 5.0000e-04
# Epoch 17/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 255s 2s/step - accuracy: 0.9658 - loss: 0.2959 - val_accuracy: 0.9541 - val_loss: 0.3185 - learning_rate: 5.0000e-04
# Epoch 18/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 255s 2s/step - accuracy: 0.9658 - loss: 0.3006 - val_accuracy: 0.9589 - val_loss: 0.3069 - learning_rate: 5.0000e-04
# Epoch 19/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 256s 2s/step - accuracy: 0.9746 - loss: 0.2471 - val_accuracy: 0.9608 - val_loss: 0.2835 - learning_rate: 5.0000e-04
# Epoch 20/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 255s 2s/step - accuracy: 0.9702 - loss: 0.2555 - val_accuracy: 0.8719 - val_loss: 0.5102 - learning_rate: 5.0000e-04
# Epoch 21/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 255s 2s/step - accuracy: 0.9814 - loss: 0.2166 - val_accuracy: 0.9273 - val_loss: 0.3852 - learning_rate: 5.0000e-04
# Epoch 22/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9756 - loss: 0.2645
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 256s 2s/step - accuracy: 0.9755 - loss: 0.2645 - val_accuracy: 0.9407 - val_loss: 0.3543 - learning_rate: 5.0000e-04
# Epoch 23/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 267s 2s/step - accuracy: 0.9740 - loss: 0.2337 - val_accuracy: 0.9665 - val_loss: 0.2400 - learning_rate: 2.5000e-04
# Epoch 24/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 255s 2s/step - accuracy: 0.9814 - loss: 0.1939 - val_accuracy: 0.9713 - val_loss: 0.2097 - learning_rate: 2.5000e-04
# Epoch 25/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 256s 2s/step - accuracy: 0.9863 - loss: 0.1633 - val_accuracy: 0.9761 - val_loss: 0.1876 - learning_rate: 2.5000e-04
# Fold 4 - Loss: 0.8998, Accuracy: 0.7644
#
# Training Fold 5/5...
# Epoch 1/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 262s 2s/step - accuracy: 0.8274 - loss: 3.1594 - val_accuracy: 0.2390 - val_loss: 2.6851 - learning_rate: 0.0010
# Epoch 2/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 259s 2s/step - accuracy: 0.9369 - loss: 1.3456 - val_accuracy: 0.7610 - val_loss: 1.6636 - learning_rate: 0.0010
# Epoch 3/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 260s 2s/step - accuracy: 0.9554 - loss: 1.0309 - val_accuracy: 0.7610 - val_loss: 2.2145 - learning_rate: 0.0010
# Epoch 4/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 258s 2s/step - accuracy: 0.9489 - loss: 1.0175 - val_accuracy: 0.7610 - val_loss: 2.1108 - learning_rate: 0.0010
# Epoch 5/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 259s 2s/step - accuracy: 0.9472 - loss: 0.8588 - val_accuracy: 0.7610 - val_loss: 1.6409 - learning_rate: 0.0010
# Epoch 6/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 258s 2s/step - accuracy: 0.9520 - loss: 0.8436 - val_accuracy: 0.7610 - val_loss: 1.9138 - learning_rate: 0.0010
# Epoch 7/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 259s 2s/step - accuracy: 0.9449 - loss: 1.2504 - val_accuracy: 0.9484 - val_loss: 1.2627 - learning_rate: 0.0010
# Epoch 8/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 261s 2s/step - accuracy: 0.9548 - loss: 1.0180 - val_accuracy: 0.8681 - val_loss: 0.9575 - learning_rate: 0.0010
# Epoch 9/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 259s 2s/step - accuracy: 0.9482 - loss: 0.8094 - val_accuracy: 0.9226 - val_loss: 0.8332 - learning_rate: 0.0010
# Epoch 10/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 258s 2s/step - accuracy: 0.9443 - loss: 0.7494 - val_accuracy: 0.8365 - val_loss: 0.8615 - learning_rate: 0.0010
# Epoch 11/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 259s 2s/step - accuracy: 0.9534 - loss: 0.6188 - val_accuracy: 0.4560 - val_loss: 1.7981 - learning_rate: 0.0010
# Epoch 12/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 264s 2s/step - accuracy: 0.9583 - loss: 0.6971 - val_accuracy: 0.9570 - val_loss: 0.6907 - learning_rate: 0.0010
# Epoch 13/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 255s 2s/step - accuracy: 0.9547 - loss: 0.6616 - val_accuracy: 0.9608 - val_loss: 0.6520 - learning_rate: 0.0010
# Epoch 14/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 255s 2s/step - accuracy: 0.9509 - loss: 0.6926 - val_accuracy: 0.9331 - val_loss: 0.6977 - learning_rate: 0.0010
# Epoch 15/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 255s 2s/step - accuracy: 0.9501 - loss: 0.6056 - val_accuracy: 0.8337 - val_loss: 1.1804 - learning_rate: 0.0010
# Epoch 16/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 256s 2s/step - accuracy: 0.9476 - loss: 0.7640 - val_accuracy: 0.9532 - val_loss: 0.6453 - learning_rate: 0.0010
# Epoch 17/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 256s 2s/step - accuracy: 0.9571 - loss: 0.5376 - val_accuracy: 0.9140 - val_loss: 0.5821 - learning_rate: 0.0010
# Epoch 18/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 256s 2s/step - accuracy: 0.9554 - loss: 0.4590 - val_accuracy: 0.9522 - val_loss: 0.4413 - learning_rate: 0.0010
# Epoch 19/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 255s 2s/step - accuracy: 0.9556 - loss: 0.4901 - val_accuracy: 0.8537 - val_loss: 0.7526 - learning_rate: 0.0010
# Epoch 20/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 257s 2s/step - accuracy: 0.9621 - loss: 0.4413 - val_accuracy: 0.9082 - val_loss: 0.4683 - learning_rate: 0.0010
# Epoch 21/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9604 - loss: 0.3818
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 256s 2s/step - accuracy: 0.9604 - loss: 0.3819 - val_accuracy: 0.7620 - val_loss: 3.3571 - learning_rate: 0.0010
# Epoch 22/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 256s 2s/step - accuracy: 0.9703 - loss: 0.3747 - val_accuracy: 0.8987 - val_loss: 0.4199 - learning_rate: 5.0000e-04
# Epoch 23/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 256s 2s/step - accuracy: 0.9721 - loss: 0.2709 - val_accuracy: 0.9685 - val_loss: 0.2484 - learning_rate: 5.0000e-04
# Epoch 24/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 256s 2s/step - accuracy: 0.9749 - loss: 0.2363 - val_accuracy: 0.9503 - val_loss: 0.2894 - learning_rate: 5.0000e-04
# Epoch 25/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 256s 2s/step - accuracy: 0.9732 - loss: 0.2432 - val_accuracy: 0.9694 - val_loss: 0.2465 - learning_rate: 5.0000e-04
# Fold 5 - Loss: 0.8301, Accuracy: 0.7756

# %% [markdown]
# ## K-fold Average Evaluation

# %%
results = []
for fold_idx, history in enumerate(histories):
    train_acc = history.history['accuracy'][-1]  
    train_loss = history.history['loss'][-1]  
    val_acc = history.history['val_accuracy'][-1]
    val_loss = history.history['val_loss'][-1] 
    
    test_acc = acc_per_fold[fold_idx]
    test_loss = loss_per_fold[fold_idx]

    results.append([fold_idx + 1, train_acc, train_loss, val_acc, val_loss, test_acc, test_loss])

df_results = pd.DataFrame(results, columns=["Fold", "Training Accuracy", "Training Loss", "Validation Accuracy", "Validation Loss", "Test Accuracy", "Test Loss"])

# %%
# Print formatted K-Fold results as a table
header = f"{'Fold':<6}{'Training Acc':<15}{'Training Loss':<15}{'Validation Acc':<15}{'Validation Loss':<15}{'Test Acc':<15}{'Test Loss':<15}"
print(header)
print("=" * len(header))

for fold_idx, history in enumerate(histories):
    train_acc = history.history['accuracy'][-1] 
    train_loss = history.history['loss'][-1]  
    val_acc = history.history['val_accuracy'][-1] 
    val_loss = history.history['val_loss'][-1]  
    
    test_acc = acc_per_fold[fold_idx]
    test_loss = loss_per_fold[fold_idx]

    # Print row for this fold
    row = f"{fold_idx+1:<6}{train_acc:<15.4f}{train_loss:<15.4f}{val_acc:<15.4f}{val_loss:<15.4f}{test_acc:<15.4f}{test_loss:<15.4f}"
    print(row)

print("=" * len(header))
# Out:
# Fold  Training Acc   Training Loss  Validation Acc Validation LossTest Acc       Test Loss
# ================================================================================================
# 1     0.9785         0.1860         0.9666         0.2318         0.7532         0.9859
# 2     0.9761         0.2196         0.9647         0.2539         0.7756         0.9513
# 3     0.9871         0.1267         0.9818         0.1462         0.7869         0.8454
# 4     0.9826         0.1688         0.9761         0.1876         0.7644         0.8998
# 5     0.9740         0.2344         0.9694         0.2465         0.7756         0.8301
# ================================================================================================

# %% [markdown]
# ## Best Model Performance Evaluation

# %%
# accuracy and loss
loss, accuracy = best_model.evaluate(X_test, y_test)
print("Test Accuracy:", accuracy)
print("Loss:", loss)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 271ms/step - accuracy: 0.6500 - loss: 1.3119
# Test Accuracy: 0.7868589758872986
# Loss: 0.8453675508499146

# %%
# Classification Report
y_pred = best_model.predict(X_test)
y_pred_classes = (y_pred > 0.5).astype(int)
print(classification_report(y_test, y_pred_classes))
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 273ms/step
#               precision    recall  f1-score   support
#
#            0       0.91      0.48      0.63       234
#            1       0.76      0.97      0.85       390
#
#     accuracy                           0.79       624
#    macro avg       0.83      0.73      0.74       624
# weighted avg       0.81      0.79      0.77       624

# %%
cm = confusion_matrix(y_test, y_pred_classes) 
f,ax = plt.subplots()
sns.heatmap(cm, annot=True, linewidths=0.01,cmap="BuPu",linecolor="gray", fmt= '.1f',ax=ax)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()

# %%
# Plot accuracy
plt.figure(figsize=(20, 8))
plt.plot(best_model_history.history['accuracy'])
plt.plot(best_model_history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
# Plot loss
plt.figure(figsize=(20, 8))
plt.plot(best_model_history.history['loss'])
plt.plot(best_model_history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %%
best_model.save('best_model_3.keras')

# %% [markdown]
# # PNEUMONIA CLASSIFIER
# ## BIL 443 TERM PROJECT
# ### Mert Başar Yıldırım | 211101039

# %% [markdown]
# ## Imports

# %%
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import KFold
from sklearn.utils.class_weight import compute_class_weight
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import regularizers
import os
import random
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
import warnings
warnings.filterwarnings ('ignore')
print ("tensorflow version is:",tf.__version__)
# Out:
# tensorflow version is: 2.18.0

# %% [markdown]
# ### Checking if the dataset is loaded correctly.

# %%
xray_data_dir = "../data/chest_xray"
print(os.listdir(xray_data_dir))
# Out:
# ['chest_xray', 'test', 'train', 'val']

# %% [markdown]
# ### Defining file paths

# %%
train_folder = os.path.join(xray_data_dir, "train")
test_folder = os.path.join(xray_data_dir, "test")
val_folder = os.path.join(xray_data_dir, "val")

# %% [markdown]
# ### A function for loading dataset images for each class

# %%
def load_images_from_directory(directory, image_size=(256, 256)):
    images = []
    labels = []
    class_names = sorted(os.listdir(directory))  

    for label, class_name in enumerate(class_names):
        class_path = os.path.join(directory, class_name)

        if os.path.isdir(class_path):  
            for img_name in os.listdir(class_path):
                img_path = os.path.join(class_path, img_name)
                try:
                    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
                    img = cv2.resize(img, image_size)  
                    img = np.expand_dims(img, axis=-1)  
                    images.append(img)
                    labels.append(label)
                except Exception as e:
                    print(f"Error occurred: {img_path}, Error: {e}")  

    return np.array(images), np.array(labels), class_names

# %%
try:
    X_train, y_train, class_names = load_images_from_directory(train_folder)
    X_test, y_test, _ = load_images_from_directory(test_folder)
    X_val, y_val, _ = load_images_from_directory(val_folder)

    print(f"Classes: {class_names}")
    print(f"Train dataset shape: {X_train.shape}, Labels shape: {y_train.shape}")
    print(f"Test dataset shape: {X_test.shape}, Labels shape: {y_test.shape}")
    print(f"Validation dataset shape: {X_val.shape}, Labels shape: {y_val.shape}")
except Exception as e:
    print("Error occured:", e)
# Out:
# Classes: ['NORMAL', 'PNEUMONIA']
# Train dataset shape: (5216, 256, 256, 1), Labels shape: (5216,)
# Test dataset shape: (624, 256, 256, 1), Labels shape: (624,)
# Validation dataset shape: (16, 256, 256, 1), Labels shape: (16,)

# %%
def plot_sample_images(X, y, class_names, samples_per_class=10):
    num_classes = len(class_names)
    fig, axes = plt.subplots(num_classes, samples_per_class, figsize=(samples_per_class * 2, num_classes * 2))
    fig.tight_layout(pad=3.0)
    
    for i, class_name in enumerate(class_names):
        class_indices = np.where(y == i)[0]  # Bu sınıfa ait resimlerin indeksleri
        selected_indices = random.sample(list(class_indices), min(len(class_indices), samples_per_class))  # Rastgele seç
        for j, idx in enumerate(selected_indices):
            axes[i, j].imshow(X[idx].squeeze(), cmap='gray')
            axes[i, j].axis('off')
            if j == 0:  # İlk sütunda sınıf adı göster
                axes[i, j].set_title(class_name, fontsize=12)

    plt.show()

# %%
plot_sample_images(X_train, y_train, class_names, samples_per_class=10)

# %% [markdown]
# ## The Distribution of Dataset

# %%
plt.figure(figsize=(6, 6))
plt.pie(x=[len(y_train), len(y_val), len(y_test)], labels=["Training", "Validation", "Test"], autopct='%1.1f%%', startangle=80, colors=['#ff9999','#66b3ff','#99ff99'])
plt.title("Dataset Distribution (Train / Validation / Test)")
plt.show()

# %% [markdown]
# ## Distribution of dataset classes

# %%
labels = [
    "Training-Normal", "Training-Pneumonia",
    "Validation-Normal", "Validation-Pneumonia",
    "Test-Normal", "Test-Pneumonia"
]
colors = ["red", "red", "blue", "blue", "green", "green"]

train_counts = [np.sum(y_train == 0), np.sum(y_train == 1)]
val_counts = [np.sum(y_val == 0), np.sum(y_val == 1)]
test_counts = [np.sum(y_test == 0), np.sum(y_test == 1)]
class_counts = train_counts + val_counts + test_counts

print("train-normal: "      + str(np.sum(y_train == 0)))
print("train-pneumonia: "   + str(np.sum(y_train == 1)))
print("val-normal: "        + str(np.sum(y_val == 0)))
print("val-pneumonia: "     + str(np.sum(y_val == 1)))
print("test-normal: "       + str(np.sum(y_test == 0)))
print("test-pneumonia: "    + str(np.sum(y_test == 1)))
# Out:
# train-normal: 1341
# train-pneumonia: 3875
# val-normal: 8
# val-pneumonia: 8
# test-normal: 234
# test-pneumonia: 390

# %%
# Create the bar chart
plt.figure(figsize=(10, 6))
plt.bar(labels, height=class_counts, color=['#ff9999', '#ff6666', '#66b3ff', '#3380cc', '#99ff99', '#33cc33'])
plt.xlabel("Categories")
plt.ylabel("Count")
plt.title("Distribution of Classes in Training, Validation, and Test Sets")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Data Preprocessing
# - Input images are converted to grayscale to enhance feature extraction efficiency.
# - All images are resized to a uniform shape of (256, 256, 1) to maintain consistency.
# - Pixel values are normalized to the [0,1] range to improve model performance.
# - The dataset is initially combined and then stratified into 80% training and 20% validation to ensure balanced representation.
# - K-Fold Cross-Validation is implemented with k = 5 to enhance model generalization.
# - Class weights are assigned to address class imbalance and improve model learning.

# %%
X_train = X_train / 255.0
X_val = X_val / 255.0
X_test = X_test / 255.0

# %%
X_combined = np.concatenate((X_train, X_val), axis=0)
y_combined = np.concatenate((y_train, y_val), axis=0)

# %%
k = 5
kf = KFold(n_splits=k, shuffle=True, random_state=42)

# %%
train_counts_list = []
val_counts_list = []

# Compute class distributions for each fold
for train_idx, val_idx in kf.split(y_combined):
    y_train_fold, y_val_fold = y_combined[train_idx], y_combined[val_idx]

    train_counts_list.append(len(y_train_fold))
    val_counts_list.append(len(y_val_fold))

avg_train_size = np.mean(train_counts_list)
avg_val_size = np.mean(val_counts_list)

# %%
plt.figure(figsize=(6, 6))
plt.pie([avg_train_size, avg_val_size, len(y_test)],
        labels=["Training", "Validation", "Test"],
        autopct='%1.1f%%', startangle=80,
        colors=['#ff9999', '#66b3ff', '#99ff99'])
plt.title("Dataset Distribution (Train / Validation / Test)")
plt.show()

# %%
train_class_0_list = []
train_class_1_list = []
val_class_0_list = []
val_class_1_list = []

for train_idx, val_idx in kf.split(y_combined):
    y_train_fold, y_val_fold = y_combined[train_idx], y_combined[val_idx]

    # Count classes in train and validation sets
    train_class_0_list.append(np.sum(y_train_fold == 0))
    train_class_1_list.append(np.sum(y_train_fold == 1))
    val_class_0_list.append(np.sum(y_val_fold == 0))
    val_class_1_list.append(np.sum(y_val_fold == 1))

avg_train_class_0 = np.mean(train_class_0_list)
avg_train_class_1 = np.mean(train_class_1_list)
avg_val_class_0 = np.mean(val_class_0_list)
avg_val_class_1 = np.mean(val_class_1_list)
test_class_0 = np.sum(y_test == 0)
test_class_1 = np.sum(y_test == 1)

# Labels and class counts
class_counts = [avg_train_class_0, avg_train_class_1, avg_val_class_0, avg_val_class_1, test_class_0, test_class_1]

# %%
plt.figure(figsize=(10, 6))
plt.bar(labels, height=class_counts, color=['#ff9999', '#ff6666', '#66b3ff', '#3380cc', '#99ff99', '#33cc33'])
plt.xlabel("Categories")
plt.ylabel("Count")
plt.title("Distribution of Classes in Training, Validation and Test Sets")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %%
class_labels = np.unique(y_combined) 
class_weights = compute_class_weight(class_weight="balanced", classes=class_labels, y=y_combined)
class_weight_dict = dict(zip(class_labels, class_weights))

print("Class Weights:", class_weight_dict)
# Out:
# Class Weights: {0: 1.939214232765011, 1: 0.6737058975019315}

# %% [markdown]
# # Building the CNN Model

# %%
# daha geniş ama daha sığ
def build_model():
    model = tf.keras.models.Sequential([
        tf.keras.layers.Conv2D(48, (3,3), activation='relu', input_shape=(256,256,1),
                               kernel_regularizer=regularizers.l2(0.01)),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPooling2D(),
        tf.keras.layers.Dropout(0.25),

        tf.keras.layers.Conv2D(96, (3,3), activation='relu', kernel_regularizer=regularizers.l2(0.01)),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPooling2D(),
        tf.keras.layers.Dropout(0.25),

        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(0.5),

        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])
    return model

# %%
example_model = build_model()
example_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 254, 254, 48)   │           480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 254, 254, 48)   │           192 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 127, 127, 48)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 127, 127, 48)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 125, 125, 96)   │        41,568 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 125, 125, 96)   │           384 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 62, 62, 96)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 62, 62, 96)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 369024)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │    23,617,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,660,545 (90.26 MB)
#  Trainable params: 23,660,129 (90.26 MB)
#  Non-trainable params: 416 (1.62 KB)

# %%
#early_stopping = EarlyStopping(monitor='val_loss', patience=10, mode='min', verbose=1, restore_best_weights=True)
lr_reduction = ReduceLROnPlateau(monitor='val_loss', patience=3, verbose=1, factor=0.5, min_lr=0.0001)

# K-Fold Training
fold_no = 1
acc_per_fold = []
loss_per_fold = []
histories = []
best_accuracy = 0
best_loss = float('inf')
best_model = None
best_model_history = None

for train_idx, val_idx in kf.split(X_combined):
    print(f"\nTraining Fold {fold_no}/{k}...")

    # Train & Validation Data
    X_train_fold, X_val_fold = X_combined[train_idx], X_combined[val_idx]
    y_train_fold, y_val_fold = y_combined[train_idx], y_combined[val_idx]

    # Create a New Model for Each Fold
    model = build_model()

    # Train Model
    history = model.fit(X_train_fold, y_train_fold,
                        validation_data=(X_val_fold, y_val_fold),
                        epochs=25, batch_size=32,
                        callbacks=[lr_reduction],
                        class_weight=class_weight_dict  
                    )

    histories.append(history)

    # Evaluate Model on Validation Set
    loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
    print(f"Fold {fold_no} - Loss: {loss:.4f}, Accuracy: {accuracy:.4f}")

    # Best Model Selection Logic
    if accuracy > best_accuracy or (accuracy == best_accuracy and loss < best_loss):
        best_accuracy = accuracy
        best_loss = loss
        best_model = model
        best_model_history = history

    loss_per_fold.append(loss)
    acc_per_fold.append(accuracy)

    fold_no += 1
# Out:
# Training Fold 1/5...
# Epoch 1/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 512s 4s/step - accuracy: 0.8075 - loss: 4.2186 - val_accuracy: 0.2770 - val_loss: 10.0126 - learning_rate: 0.0010
# Epoch 2/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 515s 4s/step - accuracy: 0.9276 - loss: 1.2241 - val_accuracy: 0.2770 - val_loss: 7.3996 - learning_rate: 0.0010
# Epoch 3/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 397s 3s/step - accuracy: 0.9259 - loss: 1.1478 - val_accuracy: 0.6027 - val_loss: 1.7015 - learning_rate: 0.0010
# Epoch 4/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 536s 4s/step - accuracy: 0.9322 - loss: 1.1669 - val_accuracy: 0.7431 - val_loss: 2.2583 - learning_rate: 0.0010
# Epoch 5/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 538s 4s/step - accuracy: 0.9350 - loss: 1.6015 - val_accuracy: 0.8825 - val_loss: 3.3632 - learning_rate: 0.0010
# Epoch 6/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9271 - loss: 3.2549
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 533s 4s/step - accuracy: 0.9271 - loss: 3.2532 - val_accuracy: 0.8787 - val_loss: 2.6172 - learning_rate: 0.0010
# Epoch 7/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 509s 4s/step - accuracy: 0.9411 - loss: 2.0543 - val_accuracy: 0.9121 - val_loss: 1.4648 - learning_rate: 5.0000e-04
# Epoch 8/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 520s 4s/step - accuracy: 0.9483 - loss: 1.3852 - val_accuracy: 0.8395 - val_loss: 1.7065 - learning_rate: 5.0000e-04
# Epoch 9/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 415s 3s/step - accuracy: 0.9446 - loss: 1.5115 - val_accuracy: 0.9274 - val_loss: 1.0530 - learning_rate: 5.0000e-04
# Epoch 10/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 461s 4s/step - accuracy: 0.9532 - loss: 1.0972 - val_accuracy: 0.9284 - val_loss: 1.1323 - learning_rate: 5.0000e-04
# Epoch 11/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 387s 3s/step - accuracy: 0.9593 - loss: 1.0585 - val_accuracy: 0.8309 - val_loss: 1.4631 - learning_rate: 5.0000e-04
# Epoch 12/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9567 - loss: 1.0079
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 386s 3s/step - accuracy: 0.9567 - loss: 1.0078 - val_accuracy: 0.7230 - val_loss: 3.9148 - learning_rate: 5.0000e-04
# Epoch 13/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 385s 3s/step - accuracy: 0.9588 - loss: 0.8874 - val_accuracy: 0.7861 - val_loss: 1.1311 - learning_rate: 2.5000e-04
# Epoch 14/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 386s 3s/step - accuracy: 0.9591 - loss: 0.6746 - val_accuracy: 0.9570 - val_loss: 0.6773 - learning_rate: 2.5000e-04
# Epoch 15/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 387s 3s/step - accuracy: 0.9672 - loss: 0.6564 - val_accuracy: 0.7259 - val_loss: 1.6212 - learning_rate: 2.5000e-04
# Epoch 16/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 385s 3s/step - accuracy: 0.9625 - loss: 0.6959 - val_accuracy: 0.8309 - val_loss: 1.0245 - learning_rate: 2.5000e-04
# Epoch 17/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 385s 3s/step - accuracy: 0.9693 - loss: 0.6165 - val_accuracy: 0.9456 - val_loss: 0.6321 - learning_rate: 2.5000e-04
# Epoch 18/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 384s 3s/step - accuracy: 0.9677 - loss: 0.5315 - val_accuracy: 0.7755 - val_loss: 1.1203 - learning_rate: 2.5000e-04
# Epoch 19/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 369s 3s/step - accuracy: 0.9717 - loss: 0.5292 - val_accuracy: 0.7440 - val_loss: 1.1361 - learning_rate: 2.5000e-04
# Epoch 20/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9597 - loss: 0.5808
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 374s 3s/step - accuracy: 0.9597 - loss: 0.5811 - val_accuracy: 0.8625 - val_loss: 1.0496 - learning_rate: 2.5000e-04
# Epoch 21/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 370s 3s/step - accuracy: 0.9755 - loss: 0.5610 - val_accuracy: 0.9026 - val_loss: 0.6447 - learning_rate: 1.2500e-04
# Epoch 22/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 371s 3s/step - accuracy: 0.9847 - loss: 0.3718 - val_accuracy: 0.9790 - val_loss: 0.3539 - learning_rate: 1.2500e-04
# Epoch 23/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 369s 3s/step - accuracy: 0.9815 - loss: 0.3381 - val_accuracy: 0.9608 - val_loss: 0.4070 - learning_rate: 1.2500e-04
# Epoch 24/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 369s 3s/step - accuracy: 0.9817 - loss: 0.3369 - val_accuracy: 0.9446 - val_loss: 0.3802 - learning_rate: 1.2500e-04
# Epoch 25/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9852 - loss: 0.2929
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0001.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 370s 3s/step - accuracy: 0.9851 - loss: 0.2932 - val_accuracy: 0.6533 - val_loss: 2.0221 - learning_rate: 1.2500e-04
# Fold 1 - Loss: 1.1280, Accuracy: 0.7756
#
# Training Fold 2/5...
# Epoch 1/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 374s 3s/step - accuracy: 0.8065 - loss: 4.1478 - val_accuracy: 0.2569 - val_loss: 7.8856 - learning_rate: 0.0010
# Epoch 2/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 370s 3s/step - accuracy: 0.9187 - loss: 1.5782 - val_accuracy: 0.7106 - val_loss: 2.5554 - learning_rate: 0.0010
# Epoch 3/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 369s 3s/step - accuracy: 0.9352 - loss: 1.8364 - val_accuracy: 0.7431 - val_loss: 1.8512 - learning_rate: 0.0010
# Epoch 4/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 369s 3s/step - accuracy: 0.9388 - loss: 1.2614 - val_accuracy: 0.7431 - val_loss: 2.3306 - learning_rate: 0.0010
# Epoch 5/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 376s 3s/step - accuracy: 0.9384 - loss: 1.5988 - val_accuracy: 0.8949 - val_loss: 2.1232 - learning_rate: 0.0010
# Epoch 6/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 369s 3s/step - accuracy: 0.9317 - loss: 1.6923 - val_accuracy: 0.9542 - val_loss: 1.4972 - learning_rate: 0.0010
# Epoch 7/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 378s 3s/step - accuracy: 0.9473 - loss: 1.5873 - val_accuracy: 0.4670 - val_loss: 4.8232 - learning_rate: 0.0010
# Epoch 8/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 377s 3s/step - accuracy: 0.9344 - loss: 2.8651 - val_accuracy: 0.2569 - val_loss: 13.0113 - learning_rate: 0.0010
# Epoch 9/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 375s 3s/step - accuracy: 0.9373 - loss: 2.1346 - val_accuracy: 0.9035 - val_loss: 1.1864 - learning_rate: 0.0010
# Epoch 10/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 375s 3s/step - accuracy: 0.9412 - loss: 1.1771 - val_accuracy: 0.9503 - val_loss: 1.3947 - learning_rate: 0.0010
# Epoch 11/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 376s 3s/step - accuracy: 0.9469 - loss: 1.7772 - val_accuracy: 0.2569 - val_loss: 12.3651 - learning_rate: 0.0010
# Epoch 12/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9354 - loss: 2.5439
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 374s 3s/step - accuracy: 0.9353 - loss: 2.5435 - val_accuracy: 0.8004 - val_loss: 2.3007 - learning_rate: 0.0010
# Epoch 13/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 374s 3s/step - accuracy: 0.9443 - loss: 1.6299 - val_accuracy: 0.9207 - val_loss: 1.1972 - learning_rate: 5.0000e-04
# Epoch 14/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 380s 3s/step - accuracy: 0.9459 - loss: 1.0260 - val_accuracy: 0.7698 - val_loss: 1.7639 - learning_rate: 5.0000e-04
# Epoch 15/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9485 - loss: 1.1763
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 375s 3s/step - accuracy: 0.9485 - loss: 1.1770 - val_accuracy: 0.9389 - val_loss: 1.4883 - learning_rate: 5.0000e-04
# Epoch 16/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 374s 3s/step - accuracy: 0.9539 - loss: 1.2060 - val_accuracy: 0.9494 - val_loss: 0.8979 - learning_rate: 2.5000e-04
# Epoch 17/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 374s 3s/step - accuracy: 0.9734 - loss: 0.7500 - val_accuracy: 0.9360 - val_loss: 0.9090 - learning_rate: 2.5000e-04
# Epoch 18/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 376s 3s/step - accuracy: 0.9619 - loss: 0.7691 - val_accuracy: 0.8567 - val_loss: 0.9453 - learning_rate: 2.5000e-04
# Epoch 19/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 375s 3s/step - accuracy: 0.9698 - loss: 0.6261 - val_accuracy: 0.9351 - val_loss: 0.6985 - learning_rate: 2.5000e-04
# Epoch 20/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 374s 3s/step - accuracy: 0.9699 - loss: 0.5667 - val_accuracy: 0.9790 - val_loss: 0.5377 - learning_rate: 2.5000e-04
# Epoch 21/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 374s 3s/step - accuracy: 0.9700 - loss: 0.5388 - val_accuracy: 0.8262 - val_loss: 0.8391 - learning_rate: 2.5000e-04
# Epoch 22/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 374s 3s/step - accuracy: 0.9719 - loss: 0.5318 - val_accuracy: 0.9303 - val_loss: 0.8306 - learning_rate: 2.5000e-04
# Epoch 23/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9697 - loss: 0.6269
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 374s 3s/step - accuracy: 0.9697 - loss: 0.6267 - val_accuracy: 0.8052 - val_loss: 0.9490 - learning_rate: 2.5000e-04
# Epoch 24/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 382s 3s/step - accuracy: 0.9730 - loss: 0.5037 - val_accuracy: 0.8959 - val_loss: 0.6425 - learning_rate: 1.2500e-04
# Epoch 25/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 376s 3s/step - accuracy: 0.9813 - loss: 0.3887 - val_accuracy: 0.9360 - val_loss: 0.4213 - learning_rate: 1.2500e-04
# Fold 2 - Loss: 1.7469, Accuracy: 0.6538
#
# Training Fold 3/5...
# Epoch 1/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 379s 3s/step - accuracy: 0.7777 - loss: 4.8870 - val_accuracy: 0.2333 - val_loss: 33.1052 - learning_rate: 0.0010
# Epoch 2/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 375s 3s/step - accuracy: 0.9172 - loss: 1.6952 - val_accuracy: 0.3614 - val_loss: 2.3802 - learning_rate: 0.0010
# Epoch 3/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 376s 3s/step - accuracy: 0.9135 - loss: 1.9049 - val_accuracy: 0.8528 - val_loss: 2.2064 - learning_rate: 0.0010
# Epoch 4/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 376s 3s/step - accuracy: 0.9337 - loss: 1.7921 - val_accuracy: 0.7667 - val_loss: 2.0971 - learning_rate: 0.0010
# Epoch 5/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 374s 3s/step - accuracy: 0.9360 - loss: 1.6401 - val_accuracy: 0.5354 - val_loss: 2.3848 - learning_rate: 0.0010
# Epoch 6/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 377s 3s/step - accuracy: 0.9346 - loss: 1.7758 - val_accuracy: 0.7667 - val_loss: 17.2055 - learning_rate: 0.0010
# Epoch 7/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9388 - loss: 2.1139
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 375s 3s/step - accuracy: 0.9387 - loss: 2.1140 - val_accuracy: 0.4570 - val_loss: 2.4045 - learning_rate: 0.0010
# Epoch 8/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 379s 3s/step - accuracy: 0.9417 - loss: 1.2288 - val_accuracy: 0.7935 - val_loss: 1.5225 - learning_rate: 5.0000e-04
# Epoch 9/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 379s 3s/step - accuracy: 0.9441 - loss: 1.2748 - val_accuracy: 0.9675 - val_loss: 0.8976 - learning_rate: 5.0000e-04
# Epoch 10/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 374s 3s/step - accuracy: 0.9422 - loss: 0.9420 - val_accuracy: 0.2533 - val_loss: 4.2692 - learning_rate: 5.0000e-04
# Epoch 11/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 376s 3s/step - accuracy: 0.9462 - loss: 0.9993 - val_accuracy: 0.8480 - val_loss: 1.2596 - learning_rate: 5.0000e-04
# Epoch 12/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9451 - loss: 0.8841
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 376s 3s/step - accuracy: 0.9452 - loss: 0.8836 - val_accuracy: 0.8489 - val_loss: 0.9648 - learning_rate: 5.0000e-04
# Epoch 13/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 376s 3s/step - accuracy: 0.9697 - loss: 0.6411 - val_accuracy: 0.9732 - val_loss: 0.4602 - learning_rate: 2.5000e-04
# Epoch 14/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 377s 3s/step - accuracy: 0.9580 - loss: 0.5080 - val_accuracy: 0.9742 - val_loss: 0.4359 - learning_rate: 2.5000e-04
# Epoch 15/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 375s 3s/step - accuracy: 0.9721 - loss: 0.4146 - val_accuracy: 0.9828 - val_loss: 0.5237 - learning_rate: 2.5000e-04
# Epoch 16/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 375s 3s/step - accuracy: 0.9621 - loss: 0.5087 - val_accuracy: 0.9771 - val_loss: 0.4477 - learning_rate: 2.5000e-04
# Epoch 17/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9708 - loss: 0.5091
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 375s 3s/step - accuracy: 0.9708 - loss: 0.5090 - val_accuracy: 0.8853 - val_loss: 0.6289 - learning_rate: 2.5000e-04
# Epoch 18/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 380s 3s/step - accuracy: 0.9745 - loss: 0.3954 - val_accuracy: 0.9828 - val_loss: 0.3181 - learning_rate: 1.2500e-04
# Epoch 19/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 376s 3s/step - accuracy: 0.9885 - loss: 0.2893 - val_accuracy: 0.9646 - val_loss: 0.3154 - learning_rate: 1.2500e-04
# Epoch 20/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 375s 3s/step - accuracy: 0.9817 - loss: 0.2568 - val_accuracy: 0.9713 - val_loss: 0.3045 - learning_rate: 1.2500e-04
# Epoch 21/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 376s 3s/step - accuracy: 0.9881 - loss: 0.2432 - val_accuracy: 0.9790 - val_loss: 0.2944 - learning_rate: 1.2500e-04
# Epoch 22/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 376s 3s/step - accuracy: 0.9718 - loss: 0.3307 - val_accuracy: 0.7667 - val_loss: 4.2220 - learning_rate: 1.2500e-04
# Epoch 23/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 375s 3s/step - accuracy: 0.9757 - loss: 0.3255 - val_accuracy: 0.9512 - val_loss: 0.3702 - learning_rate: 1.2500e-04
# Epoch 24/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9825 - loss: 0.2695
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0001.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 376s 3s/step - accuracy: 0.9825 - loss: 0.2695 - val_accuracy: 0.9742 - val_loss: 0.2963 - learning_rate: 1.2500e-04
# Epoch 25/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 376s 3s/step - accuracy: 0.9808 - loss: 0.2675 - val_accuracy: 0.9618 - val_loss: 0.3002 - learning_rate: 1.0000e-04
# Fold 3 - Loss: 0.5832, Accuracy: 0.8526
#
# Training Fold 4/5...
# Epoch 1/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 382s 3s/step - accuracy: 0.8132 - loss: 3.9643 - val_accuracy: 0.7170 - val_loss: 5.3495 - learning_rate: 0.0010
# Epoch 2/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 376s 3s/step - accuracy: 0.9220 - loss: 1.9373 - val_accuracy: 0.2868 - val_loss: 8.2375 - learning_rate: 0.0010
# Epoch 3/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 380s 3s/step - accuracy: 0.9254 - loss: 1.5850 - val_accuracy: 0.2878 - val_loss: 4.4613 - learning_rate: 0.0010
# Epoch 4/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 376s 3s/step - accuracy: 0.9248 - loss: 1.7278 - val_accuracy: 0.7180 - val_loss: 1.1329 - learning_rate: 0.0010
# Epoch 5/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 376s 3s/step - accuracy: 0.9313 - loss: 1.1276 - val_accuracy: 0.7677 - val_loss: 1.9169 - learning_rate: 0.0010
# Epoch 6/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 376s 3s/step - accuracy: 0.9268 - loss: 2.5453 - val_accuracy: 0.7208 - val_loss: 3.5889 - learning_rate: 0.0010
# Epoch 7/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9408 - loss: 2.3551
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 385s 3s/step - accuracy: 0.9407 - loss: 2.3566 - val_accuracy: 0.6587 - val_loss: 3.3068 - learning_rate: 0.0010
# Epoch 8/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 371s 3s/step - accuracy: 0.9343 - loss: 1.8180 - val_accuracy: 0.7170 - val_loss: 2.9207 - learning_rate: 5.0000e-04
# Epoch 9/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 370s 3s/step - accuracy: 0.9461 - loss: 1.2309 - val_accuracy: 0.9551 - val_loss: 0.9831 - learning_rate: 5.0000e-04
# Epoch 10/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 371s 3s/step - accuracy: 0.9398 - loss: 1.0106 - val_accuracy: 0.9197 - val_loss: 1.3843 - learning_rate: 5.0000e-04
# Epoch 11/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 370s 3s/step - accuracy: 0.9290 - loss: 1.5947 - val_accuracy: 0.9273 - val_loss: 1.4985 - learning_rate: 5.0000e-04
# Epoch 12/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9463 - loss: 1.4062
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 374s 3s/step - accuracy: 0.9463 - loss: 1.4056 - val_accuracy: 0.3910 - val_loss: 2.8826 - learning_rate: 5.0000e-04
# Epoch 13/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 369s 3s/step - accuracy: 0.9569 - loss: 0.9489 - val_accuracy: 0.9417 - val_loss: 0.9406 - learning_rate: 2.5000e-04
# Epoch 14/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 369s 3s/step - accuracy: 0.9617 - loss: 0.8139 - val_accuracy: 0.4273 - val_loss: 2.5230 - learning_rate: 2.5000e-04
# Epoch 15/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 369s 3s/step - accuracy: 0.9590 - loss: 0.8429 - val_accuracy: 0.9646 - val_loss: 0.7028 - learning_rate: 2.5000e-04
# Epoch 16/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 369s 3s/step - accuracy: 0.9591 - loss: 0.7055 - val_accuracy: 0.9656 - val_loss: 0.5252 - learning_rate: 2.5000e-04
# Epoch 17/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 369s 3s/step - accuracy: 0.9553 - loss: 0.6425 - val_accuracy: 0.8872 - val_loss: 1.0028 - learning_rate: 2.5000e-04
# Epoch 18/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 369s 3s/step - accuracy: 0.9576 - loss: 0.7070 - val_accuracy: 0.9656 - val_loss: 0.7359 - learning_rate: 2.5000e-04
# Epoch 19/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9675 - loss: 0.6315
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 370s 3s/step - accuracy: 0.9674 - loss: 0.6315 - val_accuracy: 0.8690 - val_loss: 0.9363 - learning_rate: 2.5000e-04
# Epoch 20/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 369s 3s/step - accuracy: 0.9632 - loss: 0.6858 - val_accuracy: 0.8805 - val_loss: 0.7094 - learning_rate: 1.2500e-04
# Epoch 21/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 369s 3s/step - accuracy: 0.9725 - loss: 0.4801 - val_accuracy: 0.9350 - val_loss: 0.5457 - learning_rate: 1.2500e-04
# Epoch 22/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 375s 3s/step - accuracy: 0.9671 - loss: 0.4199 - val_accuracy: 0.9732 - val_loss: 0.4144 - learning_rate: 1.2500e-04
# Epoch 23/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 369s 3s/step - accuracy: 0.9774 - loss: 0.3897 - val_accuracy: 0.9063 - val_loss: 0.5654 - learning_rate: 1.2500e-04
# Epoch 24/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 370s 3s/step - accuracy: 0.9714 - loss: 0.3711 - val_accuracy: 0.9771 - val_loss: 0.3470 - learning_rate: 1.2500e-04
# Epoch 25/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 375s 3s/step - accuracy: 0.9779 - loss: 0.3277 - val_accuracy: 0.9675 - val_loss: 0.3509 - learning_rate: 1.2500e-04
# Fold 4 - Loss: 1.1764, Accuracy: 0.7340
#
# Training Fold 5/5...
# Epoch 1/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 381s 3s/step - accuracy: 0.7966 - loss: 4.6926 - val_accuracy: 0.2390 - val_loss: 50.1088 - learning_rate: 0.0010
# Epoch 2/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 370s 3s/step - accuracy: 0.9327 - loss: 1.5913 - val_accuracy: 0.2390 - val_loss: 11.4534 - learning_rate: 0.0010
# Epoch 3/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 368s 3s/step - accuracy: 0.9318 - loss: 1.5510 - val_accuracy: 0.7610 - val_loss: 2.9775 - learning_rate: 0.0010
# Epoch 4/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 371s 3s/step - accuracy: 0.9331 - loss: 1.8271 - val_accuracy: 0.7629 - val_loss: 1.5534 - learning_rate: 0.0010
# Epoch 5/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 369s 3s/step - accuracy: 0.9308 - loss: 1.7726 - val_accuracy: 0.7610 - val_loss: 3.5926 - learning_rate: 0.0010
# Epoch 6/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 370s 3s/step - accuracy: 0.9423 - loss: 1.7198 - val_accuracy: 0.9273 - val_loss: 1.7514 - learning_rate: 0.0010
# Epoch 7/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9267 - loss: 2.2782
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 372s 3s/step - accuracy: 0.9267 - loss: 2.2791 - val_accuracy: 0.8662 - val_loss: 2.0616 - learning_rate: 0.0010
# Epoch 8/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 369s 3s/step - accuracy: 0.9502 - loss: 1.6245 - val_accuracy: 0.8901 - val_loss: 1.3940 - learning_rate: 5.0000e-04
# Epoch 9/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 369s 3s/step - accuracy: 0.9638 - loss: 1.2447 - val_accuracy: 0.8222 - val_loss: 1.4902 - learning_rate: 5.0000e-04
# Epoch 10/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 369s 3s/step - accuracy: 0.9657 - loss: 1.1201 - val_accuracy: 0.9665 - val_loss: 1.0632 - learning_rate: 5.0000e-04
# Epoch 11/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 369s 3s/step - accuracy: 0.9601 - loss: 0.9643 - val_accuracy: 0.8595 - val_loss: 1.5988 - learning_rate: 5.0000e-04
# Epoch 12/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 369s 3s/step - accuracy: 0.9602 - loss: 1.1290 - val_accuracy: 0.8432 - val_loss: 1.2441 - learning_rate: 5.0000e-04
# Epoch 13/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 368s 3s/step - accuracy: 0.9628 - loss: 0.9709 - val_accuracy: 0.8920 - val_loss: 1.0517 - learning_rate: 5.0000e-04
# Epoch 14/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 369s 3s/step - accuracy: 0.9536 - loss: 1.0387 - val_accuracy: 0.5440 - val_loss: 2.6493 - learning_rate: 5.0000e-04
# Epoch 15/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 373s 3s/step - accuracy: 0.9369 - loss: 1.4710 - val_accuracy: 0.6157 - val_loss: 2.2203 - learning_rate: 5.0000e-04
# Epoch 16/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9390 - loss: 1.3611
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 374s 3s/step - accuracy: 0.9389 - loss: 1.3628 - val_accuracy: 0.7925 - val_loss: 2.1889 - learning_rate: 5.0000e-04
# Epoch 17/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 370s 3s/step - accuracy: 0.9569 - loss: 1.5385 - val_accuracy: 0.8633 - val_loss: 1.2523 - learning_rate: 2.5000e-04
# Epoch 18/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 370s 3s/step - accuracy: 0.9644 - loss: 1.0643 - val_accuracy: 0.9111 - val_loss: 1.1394 - learning_rate: 2.5000e-04
# Epoch 19/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9608 - loss: 1.0215
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 369s 3s/step - accuracy: 0.9608 - loss: 1.0211 - val_accuracy: 0.8690 - val_loss: 1.1306 - learning_rate: 2.5000e-04
# Epoch 20/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 370s 3s/step - accuracy: 0.9734 - loss: 0.7743 - val_accuracy: 0.9761 - val_loss: 0.6576 - learning_rate: 1.2500e-04
# Epoch 21/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 371s 3s/step - accuracy: 0.9725 - loss: 0.6226 - val_accuracy: 0.9694 - val_loss: 0.5932 - learning_rate: 1.2500e-04
# Epoch 22/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 370s 3s/step - accuracy: 0.9809 - loss: 0.5585 - val_accuracy: 0.9608 - val_loss: 0.5863 - learning_rate: 1.2500e-04
# Epoch 23/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 369s 3s/step - accuracy: 0.9863 - loss: 0.5155 - val_accuracy: 0.8384 - val_loss: 0.9392 - learning_rate: 1.2500e-04
# Epoch 24/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 374s 3s/step - accuracy: 0.9742 - loss: 0.4859 - val_accuracy: 0.9685 - val_loss: 0.5225 - learning_rate: 1.2500e-04
# Epoch 25/25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 370s 3s/step - accuracy: 0.9834 - loss: 0.4609 - val_accuracy: 0.9665 - val_loss: 0.4785 - learning_rate: 1.2500e-04
# Fold 5 - Loss: 1.0059, Accuracy: 0.7997

# %% [markdown]
# ## K-fold Average Evaluation

# %%
results = []
for fold_idx, history in enumerate(histories):
    train_acc = history.history['accuracy'][-1]  
    train_loss = history.history['loss'][-1]  
    val_acc = history.history['val_accuracy'][-1]
    val_loss = history.history['val_loss'][-1] 
    
    test_acc = acc_per_fold[fold_idx]
    test_loss = loss_per_fold[fold_idx]

    results.append([fold_idx + 1, train_acc, train_loss, val_acc, val_loss, test_acc, test_loss])

df_results = pd.DataFrame(results, columns=["Fold", "Training Accuracy", "Training Loss", "Validation Accuracy", "Validation Loss", "Test Accuracy", "Test Loss"])

# %%
# Print formatted K-Fold results as a table
header = f"{'Fold':<6}{'Training Acc':<15}{'Training Loss':<15}{'Validation Acc':<15}{'Validation Loss':<15}{'Test Acc':<15}{'Test Loss':<15}"
print(header)
print("=" * len(header))

for fold_idx, history in enumerate(histories):
    train_acc = history.history['accuracy'][-1] 
    train_loss = history.history['loss'][-1]  
    val_acc = history.history['val_accuracy'][-1] 
    val_loss = history.history['val_loss'][-1]  
    
    test_acc = acc_per_fold[fold_idx]
    test_loss = loss_per_fold[fold_idx]

    # Print row for this fold
    row = f"{fold_idx+1:<6}{train_acc:<15.4f}{train_loss:<15.4f}{val_acc:<15.4f}{val_loss:<15.4f}{test_acc:<15.4f}{test_loss:<15.4f}"
    print(row)

print("=" * len(header))
# Out:
# Fold  Training Acc   Training Loss  Validation Acc Validation LossTest Acc       Test Loss
# ================================================================================================
# 1     0.9778         0.3403         0.6533         2.0221         0.7756         1.1280
# 2     0.9826         0.3649         0.9360         0.4213         0.6538         1.7469
# 3     0.9845         0.2522         0.9618         0.3002         0.8526         0.5832
# 4     0.9752         0.3281         0.9675         0.3509         0.7340         1.1764
# 5     0.9826         0.4437         0.9665         0.4785         0.7997         1.0059
# ================================================================================================

# %% [markdown]
# ## Best Model Performance Evaluation

# %%
# accuracy and loss
loss, accuracy = best_model.evaluate(X_test, y_test)
print("Test Accuracy:", accuracy)
print("Loss:", loss)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 386ms/step - accuracy: 0.7818 - loss: 0.7789
# Test Accuracy: 0.8525640964508057
# Loss: 0.5832041501998901

# %%
# Classification Report
y_pred = best_model.predict(X_test)
y_pred_classes = (y_pred > 0.5).astype(int)
print(classification_report(y_test, y_pred_classes))
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 373ms/step
#               precision    recall  f1-score   support
#
#            0       0.94      0.65      0.77       234
#            1       0.82      0.98      0.89       390
#
#     accuracy                           0.85       624
#    macro avg       0.88      0.81      0.83       624
# weighted avg       0.87      0.85      0.85       624

# %%
cm = confusion_matrix(y_test, y_pred_classes) 
f,ax = plt.subplots()
sns.heatmap(cm, annot=True, linewidths=0.01,cmap="BuPu",linecolor="gray", fmt= '.1f',ax=ax)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()

# %%
# Plot accuracy
plt.figure(figsize=(20, 8))
plt.plot(best_model_history.history['accuracy'])
plt.plot(best_model_history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
# Plot loss
plt.figure(figsize=(20, 8))
plt.plot(best_model_history.history['loss'])
plt.plot(best_model_history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %%
best_model.save('best_model_2.keras')
